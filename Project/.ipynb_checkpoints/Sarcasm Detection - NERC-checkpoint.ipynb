# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # visualizations and charts
import nltk
import pprint
from nltk.chunk import ne_chunk
from tqdm import tqdm
import sys

# %%
data = pd.read_csv('train-balanced-sarcasm.csv')
empty_comments = data["comment"].isna()
empty_comments = data[empty_comments].index
data.drop(empty_comments, axis=0, inplace=True)

# %%
### how many comments do you want to process WARNING can take some time
comments_0 = data[data['label']==0]['comment']
comments_1 = data[data['label']==1]['comment']

# %%
def comment_label(comments, label):
    processed = []
    for comment in comments:
        processed.append([comment, label])
    return processed

# %%
def comment_nerc(comments, label):
    processed = []
    with tqdm(total=len(comments), file=sys.stdout) as pbar:    
        for i, comment in enumerate(comments):
            tokenize = nltk.word_tokenize(comment)
            postag = nltk.pos_tag(tokenize)
            tagged_nerc = ne_chunk(postag)
            processed.append([tagged_nerc, label])
            
            pbar.set_description('processed: %d' % (1 + i))
            pbar.update(1)
    return processed

# %%
labelled_0 = comment_label(comments_0, 0)

# %%
nerc_0 = comment_nerc(comments_0, 0)
#error is fixed but i'm not running this again
# Out:
# processed: 505405: 100%|█████████████████████████████████████████████████████| 505405/505405 [3:20:26<00:00, 42.02it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-35449bcce041> in <module>
#       1 nerc_0 = comment_nerc(comments_0, 0)
#       2 file1 = open("nerc_0.txt", "w+")
# ----> 3 file1.write(nerc_0)
#       4
#       5 # Close opend file
#
# TypeError: write() argument must be str, not list

# %%
file1 = open("nerc_0.txt", "w+")
for item in nerc_0:
    file1.write("%s\n" % item)
    
# Close opend file
file1.close()

# %%
print(nerc_0[:2])
# Out:
# [[Tree('S', [('NC', 'NNP'), ('and', 'CC'), Tree('ORGANIZATION', [('NH', 'NNP')]), ('.', '.')]), 0], [Tree('S', [('You', 'PRP'), ('do', 'VBP'), ('know', 'VB'), ('west', 'JJS'), ('teams', 'NNS'), ('play', 'VBP'), ('against', 'IN'), ('west', 'JJ'), ('teams', 'NNS'), ('more', 'RBR'), ('than', 'IN'), ('east', 'JJ'), ('teams', 'NNS'), ('right', 'RB'), ('?', '.')]), 0]]

# %%
labelled_1 = comment_label(comments_1, 1)

# %%
nerc_1 = comment_nerc(comments_1, 1)
file2 = open("nerc_1.txt", "w+")
for item in nerc_1:
    file2.write("%s\n" % item)
    
# Close opend file
file2.close()
# Out:
# processed: 505368: 100%|████████████████████████████████████████████████████| 505368/505368 [11:46:12<00:00, 11.93it/s]

# %%
nerc0 = open('nerc_0.txt')
nerc1 = open('nerc_1.txt')

# %%
list_0 = []
for item in nerc0:
    list_0.append(item)

# %%
list_1 = []
for item in nerc1:
    list_1.append(item)

# %% [markdown]
# ### NERC visualisation

# %%
import pandas as pd
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
entities_0 = []
with tqdm(total=len(comments_0), file=sys.stdout) as pbar: 
    for i, comment in enumerate(comments_0):
        for sent in nltk.sent_tokenize(comment):
             for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
                if hasattr(chunk, 'label'):
                    entities_0.append(chunk.label() +' ' + ' '.join(c[0] for c in chunk))
        
        pbar.set_description('processed: %d' % (1 + i))
        pbar.update(1)
        
print(entities_0)
# Out:
# processed: 505405: 100%|████████████████████████████████████████████████████| 505405/505405 [14:42:39<00:00,  9.54it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
entities_1 = []
with tqdm(total=len(comments_1), file=sys.stdout) as pbar: 
    for i, comment in enumerate(comments_1):
        for sent in nltk.sent_tokenize(comment):
             for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
                if hasattr(chunk, 'label'):
                    entities_1.append(chunk.label() +' ' + ' '.join(c[0] for c in chunk))
        
        pbar.set_description('processed: %d' % (1 + i))
        pbar.update(1)

print(entities_1)
# Out:
# processed: 505368: 100%|█████████████████████████████████████████████████████| 505368/505368 [4:36:07<00:00, 30.50it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def extraction_nerc(entities):
    location = []
    organization = []
    person = []
    gpe = []
    gsp = []
    facility = []

    for entity in entities:
        pre = entity.split(' ', 1)
        if pre[0]=='LOCATION':
            location.append(pre[1])
        elif pre[0]=='ORGANIZATION':
            organization.append(pre[1])
        elif pre[0]=='PERSON':
            person.append(pre[1])
        elif pre[0]=='GPE':
            gpe.append(pre[1])
        elif pre[0]=='GSP':
            gsp.append(pre[1])
        elif pre[0]=='FACILITY':
            facility.append(pre[1])
        else:
            print('could not classify')
            print(pre)

    return(location, organization, person, gpe, gsp, facility)

# %%
#non_sarcastic comment entities
non_location, non_organization, non_person, non_gpe, non_gsp, non_facility = extraction_nerc(entities_0)

#sarcastic comment entities
location, organization, person, gpe, gsp, facility = extraction_nerc(entities_1)

# %%
wordcloud = WordCloud(background_color="white")

# %% [markdown]
# # Overall

# %%
non_all = non_location+non_organization+non_person+non_gpe+non_gsp+non_facility
all_sar = location+organization+person+gpe+gsp+facility
complete_set = non_all+all_sar

# %%
# non_sarcastic
#non_all = ''.join(non_all)
wordcloud.generate(non_all)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB6F996C8>

# %%
# sarcastic
#all_sar = ''.join(all_sar)
wordcloud.generate(all_sar)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB90B8FC8>

# %%
# all etities together
wordcloud.generate(complete_set)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FB99FABC48>

# %% [markdown]
# ## Location

# %%
print(len(non_location), len(location))
# Out:
# 531 533

# %%
# non_sarcastic
non_location = ''.join(non_location)
wordcloud.generate(non_location)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBBAEE0848>

# %%
# sarcastic
location = ''.join(location)
wordcloud.generate(location)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB79DD1C8>

# %% [markdown]
# ## Organization

# %%
print(len(non_organization), len(organization))
# Out:
# 77059 75630

# %%
# non_sarcastic
non_organization = ''.join(non_organization)
wordcloud.generate(non_organization)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBBB49D948>

# %%
# sarcastic
organization = ''.join(organization)
wordcloud.generate(organization)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB7C85548>

# %% [markdown]
# ## Person

# %%
print(len(non_person), len(person))
# Out:
# 79313 72242

# %%
# non_sarcastic
non_person = ''.join(non_person)
wordcloud.generate(non_person)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBBA1D3748>

# %%
# sarcastic
person = ''.join(person)
wordcloud.generate(person)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBA0CF6448>

# %% [markdown]
# ## Geo-Political Entity

# %%
print(len(non_gpe), len(gpe))
# Out:
# 104918 104062

# %%
# non_sarcastic
non_gpe = ''.join(non_gpe)
wordcloud.generate(non_gpe)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBBA1BAF88>

# %%
# sarcastic
gpe = ''.join(gpe)
wordcloud.generate(gpe)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB79AE7C8>

# %% [markdown]
# ## Geo-Socio-Political entity

# %%
print(len(non_gsp), len(gsp))
# Out:
# 1525 1481

# %%
# non_sarcastic
non_gsp = ''.join(non_gsp)
wordcloud.generate(non_gsp)
wordcloud.to_image()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     438                     font_size = int(2 * sizes[0] * sizes[1]
# --> 439                                     / (sizes[0] + sizes[1]))
#     440                 # quick fix for if self.layout_ contains less than 2 values
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     443                     try:
# --> 444                         font_size = sizes[0]
#     445                     except IndexError:
#
# IndexError: list index out of range
#
# ...

# %%
# sarcastic
gsp = ''.join(gsp)
wordcloud.generate(gsp)
wordcloud.to_image()

# %% [markdown]
# ## Facility

# %%
print(len(non_facility), len(facility))
# Out:
# 590 553

# %%
# non_sarcastic
non_facility = ''.join(non_facility)
wordcloud.generate(non_facility)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FBB6EBB688>

# %%
# sarcastic
facility = ''.join(facility)
wordcloud.generate(facility)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1FB865A9148>
